# %%
import ast
import os
import pandas as pd
import platform
import re
import selenium
import time
import unidecode

from time import time, sleep
from selenium import webdriver
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.wait import WebDriverWait
from unidecode import unidecode
from webdriver_manager.chrome import ChromeDriverManager

# %%
mdf = pd.read_csv('musicas.csv')
mdf.sample(5)
# Out:
#      indice_musica           titulo_musica  \
# 87              87  Te amar é massa demais
# 911            911              Logo Agora
# 97              97           Tempo de Pipa
# 116            116               Absurdo 8
# 669            669   Nu Com a Minha Música
#
#                                    nome_artista  \
# 87                                   ANAVITÓRIA
# 911                             Emílio Santiago
# 97                             Cícero Rosa Lins
# 116  Rodrigo Campos, Juçara Marçal & Gui Amabis
# 669                              Caetano Veloso
#
#                                  artistas_participacao  \
# 87                                                  []
# 911                                                 []
# 97                                                  []
# 116  ['Gui\xa0Amabis', 'Juçara\xa0Marçal', 'Rodrigo...
# 669                                                 []
#
#                                                  letra  \
# 87   [Letra de "Te amar é massa demais" com ANAVITÓ...
# 911  Agora, justamente agora\nAgoraque penso em ir ...
# 97   [Verso 1: Cícero]\nQuando você vem ou não?\nO ...
# 116  Diz, quem nasce da costela\n\nE boia na banhei...
# 669  [Verso 1]\nPenso em ficar quieto um pouquinho ...
#
#                              album data_lancamento  \
# 87                      COR (2021)    Jan. 1, 2021
# 911                Novo Millennium        1 Viewer
# 97   Canções de Apartamento (2011)   Jun. 26, 2011
# 116       Sambas do Absurdo (2017)    Feb. 9, 2017
# 669         Outras Palavras (1981)            1981
#
#                                                   tags  \
# 87   Pop,Brasil,Em Português,MPB (Música Popular Br...
# 911  Pop,Brasil,MPB (Música Popular Brasileira),Em ...
# 97   Rock,Em Português,MPB (Música Popular Brasilei...
# 116  Pop,Em Português,MPB (Música Popular Brasileir...
# 669  Pop,MPB (Música Popular Brasileira),Brasil,Em ...
#
#                                          identificador
# 87                   Te amar é massa demais ANAVITÓRIA
# 911                         Logo Agora Emílio Santiago
# 97                      Tempo de Pipa Cícero Rosa Lins
# 116  Absurdo 8 Rodrigo Campos, Juçara Marçal & Gui ...
# 669               Nu Com a Minha Música Caetano Veloso

# %%
# Quantidade de artistas distintos no CSV

mdf['nome_artista'].nunique()
# Out:
# 245

# %%
# Função que recebe um nome e retorna o link do perfil do artista correspondente no Genius 

def normaliza_nome_artista(nome_artista):
    nome_artista = nome_artista.strip().replace(u'\xa0', ' ')
    nome_decodificado = unidecode(nome_artista)
    nome_minusculo = nome_decodificado.lower()
    nome_normalizado = re.sub(r'[^a-zA-Z0-9\s]+', '', nome_minusculo)

    return nome_normalizado

def get_link_musicas_artista(nome_artista):
    nome_para_link = nome_artista.lower().capitalize().replace(' ', '-')
    link_musicas_artista = f'https://genius.com/artists/{nome_para_link}/songs'
    
    return link_musicas_artista

# %%
# Criando um DF apenas com o nome dos artistas (principais e participações) existentes

df_artistas = pd.DataFrame(mdf['nome_artista'].unique(), columns = ['nome_artista'])
df_artistas['nome_artista'] = df_artistas['nome_artista'].str.split('&')
df_artistas = df_artistas.explode('nome_artista')
df_artistas['nome_artista'] = df_artistas['nome_artista'].apply(normaliza_nome_artista)
df_artistas.reset_index(drop = True, inplace = True)

# Adicionando ao DF o link do perfil de cada artista no Genius 

df_artistas['link_musicas_artista'] = df_artistas['nome_artista'].apply(get_link_musicas_artista)
df_artistas = df_artistas.drop_duplicates(subset=['nome_artista'])

# %%
# Tamanho do DataFrame com nomes e páginas dos artistas

len(df_artistas)
# Out:
# 237

# %%
# Exibe novo DataFrame dos artistas

df_artistas.head(35)
# Out:
#            nome_artista                               link_musicas_artista
# 0            anavitoria        https://genius.com/artists/Anavitoria/songs
# 1     milton nascimento  https://genius.com/artists/Milton-nascimento/s...
# 2         chico buarque     https://genius.com/artists/Chico-buarque/songs
# 3                 silva             https://genius.com/artists/Silva/songs
# 4                anitta            https://genius.com/artists/Anitta/songs
# 5            ze ramalho        https://genius.com/artists/Ze-ramalho/songs
# 6         sergio mendes     https://genius.com/artists/Sergio-mendes/songs
# 7            vitor kley        https://genius.com/artists/Vitor-kley/songs
# 8              tim maia          https://genius.com/artists/Tim-maia/songs
# 9         legiao urbana     https://genius.com/artists/Legiao-urbana/songs
# 10            giulia be         https://genius.com/artists/Giulia-be/songs
# 11          os mutantes       https://genius.com/artists/Os-mutantes/songs
# 12           kell smith        https://genius.com/artists/Kell-smith/songs
# 13           ana vilela        https://genius.com/artists/Ana-vilela/songs
# 14            lo borges         https://genius.com/artists/Lo-borges/songs
# 15       geraldo vandre    https://genius.com/artists/Geraldo-vandre/songs
# 16          putodiparis       https://genius.com/artists/Putodiparis/songs
# 17          herve pagez       https://genius.com/artists/Herve-pagez/songs
# 18       caetano veloso    https://genius.com/artists/Caetano-veloso/songs
# 20             rita lee          https://genius.com/artists/Rita-lee/songs
# 21             belchior          https://genius.com/artists/Belchior/songs
# 22        novos baianos     https://genius.com/artists/Novos-baianos/songs
# 23  adriana calcanhotto  https://genius.com/artists/Adriana-calcanhotto...
# 24          tribalistas       https://genius.com/artists/Tribalistas/songs
# 25          marina sena       https://genius.com/artists/Marina-sena/songs
# 26            gal costa         https://genius.com/artists/Gal-costa/songs
# 27              emicida           https://genius.com/artists/Emicida/songs
# 32      vanessa da mata   https://genius.com/artists/Vanessa-da-mata/songs
# 33          raul seixas       https://genius.com/artists/Raul-seixas/songs
# 34        alceu valenca     https://genius.com/artists/Alceu-valenca/songs
# 35             juliette          https://genius.com/artists/Juliette/songs
# 36       roberto carlos    https://genius.com/artists/Roberto-carlos/songs
# 37                melim             https://genius.com/artists/Melim/songs
# 38          chico cesar       https://genius.com/artists/Chico-cesar/songs
# 39           tiago iorc        https://genius.com/artists/Tiago-iorc/songs

# %%
# Para persistir os novos dados e índices de parada

dicionario_musicas = {'indice_artista': [],
                     'indice_musica': [],
                     'titulo_musica': [],
                     'nome_artista': [],
                     'letra': [],
                     'album': [],
                     'data_lancamento': [],
                     'tags': [],
                     'identificador' : []}

musicas_df = pd.DataFrame.from_dict(dicionario_musicas)
nome_arquivo_musicas = 'musicas_artistas.csv'
indice_artista = 0
indice_musica = 0
if os.path.isfile(nome_arquivo_musicas):
    musicas_df = pd.read_csv(nome_arquivo_musicas)
    if len(musicas_df) > 0:
        indice_artista = list(musicas_df['indice_artista'])[-1]
        indice_musica = list(musicas_df['indice_musica'])[-1]
else:
    musicas_df.to_csv(nome_arquivo_musicas, index=False)

print(indice_artista, indice_musica)
# Out:
# 237 0

# %%
# Exibindo as últimas músicas coletadas

a = pd.read_csv('musicas_artistas.csv')
a.tail(50)
# Out:
#        indice_artista  indice_musica                         titulo_musica  \
# 17476             233            138               Lion Man (Instrumental)
# 17477             233            140           Samba Sambei (Instrumental)
# 17478             233            141              Sucrilhos (Instrumental)
# 17479             233            142  Freguês da Meia Noite (Instrumental)
# 17480             233            144                             Dez Anjos
# 17481             233            147                  Coroné Antônio Bento
# 17482             234              0                 Primavera (Vai Chuva)
# 17483             235             38                              De Graça
# 17484             235             39                   Tudo Bem, Tanto Faz
# 17485             235             40                      Show de Estrelas
# 17486             235             42                      Sangue do Brasil
# 17487             235             43                     O Seu Amor Sou Eu
# 17488             235             44            Canto Inicial: Emergencial
# 17489             235             45                               Vem Vem
# 17490             235             46                             Um de Nós
# 17491             235             48                       A Vida é Bélica
# 17492             235             49                                Alento
# 17493             235             53                      Melodia da Noite
# 17494             235             54                              Redenção
# 17495             235             56                          Me Sinto Bem
# 17496             235             57                              Temporal
# 17497             235             58                      Forró da Solidão
# 17498             235             59                    Saudade do Meu Pai
# 17499             235             60                          Sete Salomés
# 17500             235             61                                 Ritos
# 17501             235             62                          Palavra Amor
# 17502             235             63                            Nada a Ver
# 17503             235             64    Pense Duas Vezes Antes de Esquecer
# 17504             235             66                          Só Eu Sou Eu
# 17505             235             67                                9 Luas
# 17506             235             68                               Julieta
# 17507             236              0                       Sorriso Madeira
# 17508             236              1                          Por Quê Nós?
# 17509             236              2                         A Companheira
# 17510             236              5                            Felicidade
# 17511             236              6                                Esboço
# 17512             236              8                             Eu Sou Eu
# 17513             236              9                 Deu Pane Em São Paulo
# 17514             236             10                                Haicai
# 17515             236             11              Não resta a menor dúvida
# 17516             236             12              Gosto mais do outro lado
# 17517             236             13                       Saudade Moderna
# 17518             236             14              No Decorrer Da Madrugada
# 17519             236             15                              O Menino
# 17520             236             16                                  Luar
# 17521             236             17                        Depois Melhora
# 17522             236             18                          Seios da Voz
# 17523             236             19                       Quer Uma Coisa?
# 17524             236             20                                 Quase
# 17525             237              0                                 O Rei
#
#                             nome_artista  \
# 17476                             Criolo
# 17477                             Criolo
# 17478                             Criolo
# 17479                             Criolo
# 17480         Milton Nascimento & Criolo
# 17481                             Criolo
# 17482                             Criolo
# 17483                     Marcelo Jeneci
# 17484                     Marcelo Jeneci
# 17485                     Marcelo Jeneci
# 17486                   Russo Passapusso
# 17487                     Marcelo Jeneci
# 17488                     Marcelo Jeneci
# 17489                     Marcelo Jeneci
# 17490                     Marcelo Jeneci
# 17491                     Marcelo Jeneci
# 17492                     Marcelo Jeneci
# 17493                     Marcelo Jeneci
# 17494                     Marcelo Jeneci
# 17495                      Laura Lavieri
# 17496                     Marcelo Jeneci
# 17516                      Sopa de Concha        1 Viewer
# 17517                                 NaN        1 Viewer
# 17518                   Felicidade (1997)        1 Viewer
# 17519                   Felicidade (1997)        1 Viewer
# 17520                   Felicidade (1997)        1 Viewer
# 17521                   Felicidade (1997)        1 Viewer
# 17522                   Felicidade (1997)        1 Viewer
# 17523                   Felicidade (1997)    Nov. 1, 1997
# 17524                   Felicidade (1997)        1 Viewer
# 17525                   Felicidade (1997)        1 Viewer
#
#                                                     tags  \
# 17476                            Rap,Instrumental,Brasil
# 17477                            Rap,Instrumental,Brasil
# 17478                            Rap,Brasil,Instrumental
# 17479                            Rap,Brasil,Instrumental
# 17480  Rock,Brasil,MPB (Música Popular Brasileira),Em...
# 17481                                                Pop
# 17482                                                Pop
# 17483                                   Pop,Em Português
# 17484                                   Pop,Em Português
# 17485                                   Pop,Em Português
# 17486                      Non-Music,Brasil,Em Português
# 17487  Pop,Brasil,Em Português,MPB (Música Popular Br...
# 17488  Pop,MPB (Música Popular Brasileira),Brasil,Em ...
# 17489  Pop,Brasil,Em Português,MPB (Música Popular Br...
# 17490                                   Pop,Em Português
# 17491                                   Pop,Em Português
# 17492                                   Pop,Em Português
# 17493  Rock,Brasil,Em Português,MPB (Música Popular B...
# 17494  Rock,Pop,Brasil,Em Português,MPB (Música Popul...
# 17495                                   Pop,Em Português
# 17496                                   Pop,Em Português
# 17497  Pop,Brasil,Em Português,MPB (Música Popular Br...
# 17498  Pop,Brasil,MPB (Música Popular Brasileira),Em ...
# 17499                                   Pop,Em Português
# 17500  Pop,Brasil,Em Português,MPB (Música Popular Br...
# 17501  Pop,Brasil,Em Português,MPB (Música Popular Br...
# 17502                                   Pop,Em Português
# 17503                           Rock,Brasil,Em Português
# 17504                                                Pop
# 17505                                                Pop
# 17506                                                Pop
# 17507                                                Pop
# 17508                                   Pop,Em Português
# 17509  Pop,Acoustic,Brasil,MPB (Música Popular Brasil...
# 17510                                   Pop,Em Português
# 17511  Pop,Acoustic,Brasil,MPB (Música Popular Brasil...
# 17512  Pop,Acoustic,MPB (Música Popular Brasileira),B...
# 17513  Pop,Acoustic,Brasil,MPB (Música Popular Brasil...
# 17514                                   Pop,Em Português
# 17515                            Pop,Em Português,Brasil
# 17516                            Pop,Em Português,Brasil
# 17517                        Country,Em Português,Brasil
# 17518                                   Pop,Em Português
# 17519                                   Pop,Em Português
# 17520                                   Pop,Em Português
# 17521                                                Pop
# 17522                                                Pop
# 17523  Pop,Acoustic,MPB (Música Popular Brasileira),B...
# 17524                                                Pop
# 17525                                                Pop
#
#                                            identificador
# 17476                     Lion Man (Instrumental) Criolo
# 17477                 Samba Sambei (Instrumental) Criolo
# 17478                    Sucrilhos (Instrumental) Criolo
# 17479        Freguês da Meia Noite (Instrumental) Criolo
# 17480               Dez Anjos Milton Nascimento & Criolo
# 17481                        Coroné Antônio Bento Criolo
# 17482                       Primavera (Vai Chuva) Criolo
# 17483                            De Graça Marcelo Jeneci
# 17484                 Tudo Bem, Tanto Faz Marcelo Jeneci
# 17485                    Show de Estrelas Marcelo Jeneci
# 17486                  Sangue do Brasil Russo Passapusso
# 17487                   O Seu Amor Sou Eu Marcelo Jeneci
# 17488          Canto Inicial: Emergencial Marcelo Jeneci
# 17489                             Vem Vem Marcelo Jeneci
# 17490                           Um de Nós Marcelo Jeneci
# 17491                     A Vida é Bélica Marcelo Jeneci
# 17492                              Alento Marcelo Jeneci
# 17493                    Melodia da Noite Marcelo Jeneci
# 17494                            Redenção Marcelo Jeneci
# 17495                         Me Sinto Bem Laura Lavieri
# 17496                            Temporal Marcelo Jeneci
# 17497                      Forró da Solidão Julia Mestre
# 17498                  Saudade do Meu Pai Marcelo Jeneci
# 17499                          Sete Salomés Juliana Kehl
# 17500                               Ritos Marcelo Jeneci
# 17501                        Palavra Amor Marcelo Jeneci
# 17502                          Nada a Ver Marcelo Jeneci
# 17503         Pense Duas Vezes Antes de Esquecer Ortinho
# 17504                        Só Eu Sou Eu Marcelo Jeneci
# 17505                              9 Luas Marcelo Jeneci
# 17506                             Julieta Marcelo Jeneci
# 17507                     Sorriso Madeira Marcelo Jeneci
# 17508                        Por Quê Nós? Marcelo Jeneci
# 17509                           A Companheira Luiz Tatit
# 17510                              Felicidade Luiz Tatit
# 17511                                  Esboço Luiz Tatit
# 17512                               Eu Sou Eu Luiz Tatit
# 17513                   Deu Pane Em São Paulo Luiz Tatit
# 17514                                  Haicai Luiz Tatit
# 17515  Não resta a menor dúvida Geraldo Leite e Os Am...
# 17516  Gosto mais do outro lado Geraldo Leite e Os Am...
# 17517                         Saudade Moderna Luiz Tatit
# 17518                No Decorrer Da Madrugada Luiz Tatit
# 17519                                O Menino Luiz Tatit
# 17520                                    Luar Luiz Tatit
# 17521                          Depois Melhora Luiz Tatit
# 17522                            Seios da Voz Luiz Tatit
# 17523                         Quer Uma Coisa? Luiz Tatit
# 17524                                   Quase Luiz Tatit
# 17525                                   O Rei Luiz Tatit

# %%
# Identificando qual o sistema operacional

sistema_operacional = platform.system()
if sistema_operacional == 'Linux':
    caminho_webdriver = os.path.join('chromedriver_linux64', 'chromedriver')
elif sistema_operacional == 'Windows':
    caminho_webdriver = os.path.join('chromedriver_win64', 'chromedriver.exe')

# Criando o WebDriver
    
servico = Service(executable_path=caminho_webdriver)
opcoes = webdriver.ChromeOptions()
#opcoes.add_argument('--headless')
#opcoes.add_argument('--disable-gpu')
navegador = webdriver.Chrome(service = servico, options = opcoes)
espera_navegador = WebDriverWait(navegador, 30)
identificadores = list(musicas_df['identificador'])

for i in range(indice_artista, len(df_artistas)):
    link_musicas_artista = df_artistas['link_musicas_artista'].iloc[i]
    navegador.get(link_musicas_artista)
    navegador.execute_script("document.body.style.zoom='60%'")

    '''while True:
        script = f"window.scrollTo(0, (document.body.scrollHeight - {900}));"
        navegador.execute_script(script)
        sleep(1)
        if not (len(navegador.find_elements(By.XPATH, "//div[contains(@class, 'PlaceholderSpinner')]"))) > 0:
            break
    
    if len(navegador.find_elements(By.CLASS_NAME, 'render_404-headline')) > 0:
        continue'''
    
    tempo_maximo_espera = 100 
    tempo_inicio = time()
    while True:
        script = f"window.scrollTo(0, (document.body.scrollHeight));"
        navegador.execute_script(script)
        sleep(1)

        elementos_placeholder = navegador.find_elements(By.XPATH, "//div[contains(@class, 'PlaceholderSpinner')]")
        if not elementos_placeholder:
            break
            
        tempo_decorrido = time() - tempo_inicio
        if tempo_decorrido > tempo_maximo_espera:
            print("Tempo de espera excedido. Saindo do loop.")
            break
    
    if len(navegador.find_elements(By.CLASS_NAME, 'render_404-headline')) > 0:
        continue
    
    musicas_elementos = navegador.find_elements(By.XPATH, '//a[contains(@class, "ListItem__Link")]')
    for j in range(indice_musica, len(musicas_elementos)):

        try:
            musica = musicas_elementos[j]
            link_letra = musica.get_attribute("href")
            navegador.execute_script(f'window.open("{link_letra}","_blank");')
            navegador.switch_to.window(navegador.window_handles[1])
        except TimeoutException:
            continue

        # Captura informações importantes da música
        
        titulo_musica = ''
        titulo_musica_elemento = navegador.find_element(By.XPATH, '//span[contains(@class, "SongHeaderdesktop__HiddenMask")]')
        if titulo_musica_elemento:
            titulo_musica = titulo_musica_elemento.get_attribute("innerText")
        
        nome_artista = ''
        nome_artista_elemento = navegador.find_element(By.XPATH, '//a[contains(@class, "HeaderArtistAndTracklistdesktop__Artist")]')
        if nome_artista_elemento:
            nome_artista = nome_artista_elemento.get_attribute("innerText")
        
        identificador = f'{titulo_musica} {nome_artista}'
        
        if identificador not in identificadores:
            
            letra = ''
            try:
                identificador_containers_letra_id = '//div[@data-lyrics-container="true"]'
                containers_letra = espera_navegador.until(EC.presence_of_all_elements_located((By.XPATH, identificador_containers_letra_id)))
                for container in containers_letra:
                    letra_atual = container.get_attribute("innerText")
                    letra += letra_atual
            except Exception as e:
                print(f'Erro na letra: {str(e)}')

            album = ''
            try:
                album = navegador.find_element(By.XPATH, "//a[contains(@class, 'PrimaryAlbum')]").get_attribute("innerText")
            except Exception as e:
                print(f'Erro no nome do álbum: {str(e)}')

            data_lancamento = ''
            try:
                identificador_data_lancamento = "//span[contains(@class, 'MetadataStats')]"
                elementos_data_lancamento = navegador.find_elements(By.XPATH, identificador_data_lancamento)
                data_lancamento = elementos_data_lancamento[0].get_attribute("innerText")
            except Exception as e:
                print(f'Erro na data de lançamento: {str(e)}')

            tags = ''
            try:
                identificador_tags = "//a[contains(@class, 'SongTags__Tag')]"
                elementos_tags = navegador.find_elements(By.XPATH, identificador_tags)
                tags = ','.join([tag.get_attribute("innerText") for tag in elementos_tags])
            except Exception as e:
                print(f'Erro nas tags: {str(e)}')
            
            i_copia = i
            j_copia = j + 1
            if j ==  len(musicas_elementos) - 1:
                i_copia += 1
                j_copia = 0
                
            nova_linha = [i_copia, j_copia, titulo_musica, nome_artista, letra, album, data_lancamento, tags, identificador]
            df_nova_linha = pd.DataFrame([nova_linha])
            df_nova_linha.to_csv(nome_arquivo_musicas, mode='a', header=False, index=False)
            identificadores.append(identificador)

        janelas = navegador.window_handles
        if len(janelas) > 0:
            navegador.close()
            navegador.switch_to.window(janelas[0])
